# %%
import pandas as pd
import numpy as np
from simpledbf import Dbf5

# %%
data_nasa = pd.read_csv('./meteorite_landings.csv')
data_nasa.head()
nasa = data_nasa.copy()
nasa['year'] = np.int32(nasa['year'])
mask = ((nasa['year'] == 2013) == True)
year = nasa[mask]
year.value_counts()
# Out:
# name                   id     nametype  recclass               mass      fall   year  reclat    reclong   GeoLocation
# Chelyabinsk            57165  Valid     LL5                    100000.0  Fell   2013  54.81667  61.11667  (54.816670, 61.116670)    1
# Northwest Africa 7755  57166  Valid     Martian (shergottite)  30.0      Found  2013  0.00000   0.00000   (0.000000, 0.000000)      1
# Northwest Africa 7812  57258  Valid     Angrite                46.2      Found  2013  0.00000   0.00000   (0.000000, 0.000000)      1
# Northwest Africa 7822  57268  Valid     Achondrite-ung         45.8      Found  2013  0.00000   0.00000   (0.000000, 0.000000)      1
# Northwest Africa 7855  57420  Valid     H4                     916.0     Found  2013  0.00000   0.00000   (0.000000, 0.000000)      1
# Northwest Africa 7856  57421  Valid     LL6                    517.0     Found  2013  0.00000   0.00000   (0.000000, 0.000000)      1
# ...

# %%
data5 = pd.read_csv('./meteorite2.csv')
data6 = data5.copy()
mask = data6['year'] > 2013
df_2016 = data6[mask]
df_2016
# Out:
#                        name     id   type          recclass      mass   fall  \
# 37            Appley Bridge   2318  Valid               LL6   15000.0   Fell
# 77                   Baxter   4977  Valid                L6     611.0   Fell
# 114              Boguslavka   5098  Valid       "Iron IIAB"  256000.0   Fell
# 142                  Calivo   5200  Valid        Stone-uncl    2400.0   Fell
# 246               Ekh Khera   7777  Valid                H6     840.0   Fell
# 438             Kisvars��ny  12325  Valid                L6    1550.0   Fell
# 459             Kuttippuram  12384  Valid                L6   45000.0   Fell
# 547        Meester-Cornelis  15470  Valid                H5   24750.0   Fell
# 638             Nyir��brany  17970  Valid               LL5    1100.0   Fell
# 666               Palinshih  18077  Valid              Iron   18000.0   Fell
# 735               Rampurhat  22385  Valid                LL     100.0   Fell
# ...

# %%
nasa2 = nasa.rename(columns = {'reclat':'lat', 'reclong':'long', 'nametype':'type'})
nasa2
# Out:
#              name     id   type              recclass      mass   fall  year  \
# 0          Aachen      1  Valid                    L5      21.0   Fell  1880
# 1          Aarhus      2  Valid                    H6     720.0   Fell  1951
# 2            Abee      6  Valid                   EH4  107000.0   Fell  1952
# 3        Acapulco     10  Valid           Acapulcoite    1914.0   Fell  1976
# 4         Achiras    370  Valid                    L6     780.0   Fell  1902
# ...           ...    ...    ...                   ...       ...    ...   ...
# 45711  Zillah 002  31356  Valid               Eucrite     172.0  Found  1990
# 45712      Zinder  30409  Valid  Pallasite, ungrouped      46.0  Found  1999
# 45713        Zlin  30410  Valid                    H4       3.3  Found  1939
# 45714   Zubkovsky  31357  Valid                    L6    2167.0  Found  2003
# 45715  Zulu Queen  30414  Valid                  L3.7     200.0  Found  1976
#
# ...

# %%
data_tog = pd.concat([nasa2, df_2016], axis = 0)

# %%
data_tog.shape
# Out:
# (45766, 10)
